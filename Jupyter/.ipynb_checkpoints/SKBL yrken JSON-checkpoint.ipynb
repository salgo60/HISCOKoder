# %% [markdown]
# ### SKBL - JSON data occupation

# %% [markdown]
# * GITHUB [salgo60/HISCOKoder](https://github.com/salgo60/HISCOKoder)
#   * this [Notebook](https://github.com/salgo60/HISCOKoder/blob/main/Jupyter/SKBL%20yrken%20JSON.ipynb)
#
# SKBL är en av de få svenska aktörer som har strukturerad data för yrken och ett API. Dock saknas externa kopplingar som Wikidata och HISCOkoder.... även tid anges som textsträngar i olika format, plats saknar även det "samma som" utan blir en textsträng med koordinat.
#
# Summa sumarum bra med API men datat är långt från optimalt för att bearbetas vidare. Jag var med på SKBL ledningsgruppsmöte och pratade om Linked data 2020 dec men dom har inte orkat ta steget ännu.... se [presentation](https://docs.google.com/presentation/d/1EvQHdzPsIA4hr2WuNXnbpsLHec2GS89b_pHvilO6xhQ/edit?usp=sharing) tror inte KARP plattformen är optimal för "samma som" plus att det behövs nya kompetenser som Linked data i projektet för att det skall ta fart....
# #### Other sources we sync
# * [Arken](https://github.com/salgo60/open-data-examples/blob/master/Arken.ipynb)
#   * WD [Property:P8899](https://www.wikidata.org/wiki/Property:P8899)
# * [Kulturpersoner Uppsalakyrkogård](https://github.com/salgo60/open-data-examples/blob/master/Check%20WD%20kulturpersoner%20uppsalakyrkogardar.ipynb)
# * [Litteraturbanken](https://github.com/salgo60/open-data-examples/blob/master/Litteraturbanken%20Author.ipynb)
#   * WD property [P5101](https://www.wikidata.org/wiki/Property_talk:P5101) [P5123](https://www.wikidata.org/wiki/Property_talk:P5123)
# * [Nobelprize.org](https://github.com/salgo60/open-data-examples/blob/master/Nobel%20API.ipynb)
#   * WD [property 8024](https://www.wikidata.org/wiki/Property:P8024)
# * [SBL](https://github.com/salgo60/open-data-examples/blob/master/SBL.ipynb)
#   * WD [property 3217](https://www.wikidata.org/wiki/Property:P3217)
# * [SKBL](https://github.com/salgo60/open-data-examples/blob/master/Svenskt%20Kvinnobiografiskt%20lexikon%20part%203.ipynb)
#   * WD [property 4963](https://www.wikidata.org/wiki/Property:P4963)
# * [Svenska Akademien](https://github.com/salgo60/open-data-examples/blob/master/Svenska%20Akademien.ipynb)
#   * WD [property 5325](https://www.wikidata.org/wiki/Property:P5325)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-08-17 11:13:54.831706

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 


url = "https://ws.spraakbanken.gu.se/ws/karp/v5/query?mode=skbl&q=extended%7C%7Cand%7Cskblstatus%7Cequals%7Cok&size=10000"
r = http.request('GET', url) 
data = json.loads(r.data.decode('utf-8')) 

listSKBLYrke = []
i = 0 
for row in (data["hits"]["hits"]):
#    print(row)
#    print (row["_source"]["url"])

    new_item = dict()
    new_item['skblid'] = row["_source"]["url"]
   
    try:
        #print (row["_source"]["occupation"])
        for o in row["_source"]['occupation']:    
#            print("\t",o['description'])
#            print("\t\t",o['detail'])
#            print("\t\t",o['place'])
#            print("\t\t",o['type'])
#	 Sakkunnig
#		 Sakkunnig, bl a 1924 års privatskoleutredning
#		 {'pin': {'lat': 59.329323, 'lon': 18.068581}, 'place': 'Stockholm'}
#		 Ideellt arbete
#	 Chef
#		 VD, Kvinnornas Andelsförening Svenska Hem
#		 {'pin': {'lat': 59.329323, 'lon': 18.068581}, 'place': 'Stockholm'}
#		 Yrke
            try:
                description = o['description']
            except:
                description = ""
            new_item['description'] = description 
            try:
                detail = o['detail']               
            except:
                detail = ""
            new_item['detail'] = detail 
            try:
                Ofrom = o['from']               
            except:
                Ofrom = ""
            new_item['from'] = Ofrom 
            try:
                Oto = o['to']               
            except:
                Oto = ""
            new_item['to'] = Oto 
            try:
                place = o['place']               
            except:
                place = ""
            new_item['place'] = place 
            try:
                occupationtype = o['type']
            except:
                occupationtype = ""
            new_item['occupationtype'] = occupationtype 

    except Exception as e: 
        print("Error occupation\t",row["_source"]["url"],e)
    listSKBLYrke.append(new_item)
    i = i + 1 
    #print (i)
print (len(listSKBLYrke) ," antal poster")
# Out:
# Error occupation	 MarthaAdlerstrahle 'occupation'
# Error occupation	 EbbavonEckermann 'occupation'
# Error occupation	 AnnaBielke 'occupation'
# Error occupation	 SigridEskilsdotterBaner 'occupation'
# Error occupation	 MarieLouiseafForsell 'occupation'
# Error occupation	 GretaGiadda 'occupation'
# Error occupation	 EbbaGustavsdotterStenbock0 'occupation'
# Error occupation	 AgnetaHorn 'occupation'
# Error occupation	 ClaraAuroraLiljenroth 'occupation'
# Error occupation	 BeataRosenhane 'occupation'
# Error occupation	 MartinavonSchwerin 'occupation'
# Error occupation	 AnnaSkytte 'occupation'
# Error occupation	 EvaUpmark 'occupation'
# Error occupation	 Annaprinsessa 'occupation'
# Error occupation	 Ceciliaprinsessa 'occupation'
# Error occupation	 ElinafSkovde 'occupation'
# Error occupation	 KatarinaJagellonicadrottning 'occupation'
# 2055  antal poster

# %%
listSKBLYrke[1:10]
# Out:
# [{'skblid': 'MargitAbenius',
#   'description': 'Litteraturkritiker',
#   'detail': 'Litteraturkritiker, BLM, Ord &amp; Bild, Sveriges Radio',
#   'from': {'comment': '1933', 'date': '1933'},
#   'to': {'comment': '1967', 'date': '1967'},
#   'place': {'pin': {'lat': 59.858564, 'lon': 17.638927}, 'place': 'Uppsala'},
#   'occupationtype': 'Yrke'},
#  {'skblid': 'EuphrosyneAbrahamson',
#   'description': 'Sångare',
#   'detail': 'Operasångare',
#   'from': {'date': '1859'},
#   'to': '',
#   'place': {'pin': {'lat': '48.208174', 'lon': '16.373819'},
#    'place': 'Wien, Österrike'},
#   'occupationtype': 'Yrke'},
#  {'skblid': 'AlmaAbrahamsson',
#   'description': 'Föreläsare',
#   'detail': 'Dövtolk, föreläsare, arrangör av kurser och fritidsaktiviteter med och för döva',
#   'from': {'comment': '1930-talet'},
#   'to': {'comment': '1970-talet'},
#   'place': {'pin': {'lat': '57.70887', 'lon': '11.97456'},
#    'place': 'Göteborg'},
#   'occupationtype': 'Yrke'},
#  {'skblid': 'IngelaMargaretaAbrahamsson',
#   'description': 'Sångare',
#   'detail': 'Vissångare, textförfattare, revyartist, bl a Andra Bullar',
#   'from': {'comment': '1970-talet'},
#   'to': {'comment': '2000-talet'},
#   'place': '',
#   'occupationtype': 'Yrke'},
#  {'skblid': 'KerstinAbramNilsson0',
#   'description': 'Lärare',
#   'detail': 'Lärare, Konstfackskolan, även Gerlesborgsskolan',
#   'from': {'comment': '1971', 'date': '1971'},
#   'to': {'comment': '1989', 'date': '1989'},
#   'place': {'pin': {'lat': 59.329323, 'lon': 18.068581}, 'place': 'Stockholm'},
#   'occupationtype': 'Yrke'},
#  {'skblid': 'WilhelminaSofiaAcrel',
#   'description': 'Producent',
#   'detail': 'Filmproducent',
#   'from': {'comment': '1933', 'date': '1933'},
#   'to': {'comment': '1939', 'date': '1939'},
#   'place': {'pin': {'lat': 59.329323, 'lon': 18.068581}, 'place': 'Stockholm'},
#   'occupationtype': 'Yrke'},
#  {'skblid': 'KarinAdamsson',
#   'description': 'Handelsanställd',
#   'detail': 'Handelsbiträde, sedermera föreståndare, fr o m 1939 direktör, AB Nils Adamssons Sjukvårdsaffärer',
#   'from': '',
#   'to': '',
#   'place': {'pin': {'lat': 59.329323, 'lon': 18.068581}, 'place': 'Stockholm'},
#   'occupationtype': 'Yrke'},
#  {'skblid': 'BirgittaAdde',
#   'description': 'Jurist',
#   'detail': 'Lagman, Leksands tingsrätt',
#   'from': {'comment': '1985', 'date': '1985'},
#   'to': {'comment': '1990', 'date': '1990'},
#   'place': {'pin': {'lat': 60.730308, 'lon': 14.999892}, 'place': 'Leksand'},
#   'occupationtype': 'Yrke'},
#  {'skblid': 'MariaAdelborg',
#   'description': 'Formgivare',
#   'detail': 'Mönsterritare hos Handarbetets Vänner',
#   'from': {'date': '1900'},
#   'to': {'date': '1907'},
#   'place': {'pin': {'lat': 59.329323, 'lon': 18.068581}, 'place': 'Stockholm'},
#   'occupationtype': 'Yrke'}]

# %%
import pandas as pd
newListdf = pd.DataFrame(listSKBLYrke,columns=list
                         (["skblid","description","detail","occupationtype","from","to","place"]))

# %%
newListdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2055 entries, 0 to 2054
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   skblid          2055 non-null   object
#  1   description     2038 non-null   object
#  2   detail          2038 non-null   object
#  3   occupationtype  2038 non-null   object
#  4   from            2038 non-null   object
#  5   to              2038 non-null   object
#  6   place           2038 non-null   object
# dtypes: object(7)
# memory usage: 112.5+ KB

# %%
newListdf.head(50)
# Out:
#                            skblid                      description  \
# 0                   AstridAagesen                        Gallerist
# 1                   MargitAbenius               Litteraturkritiker
# 2            EuphrosyneAbrahamson                          Sångare
# 3                 AlmaAbrahamsson                       Föreläsare
# 4      IngelaMargaretaAbrahamsson                          Sångare
# 5            KerstinAbramNilsson0                           Lärare
# 6            WilhelminaSofiaAcrel                        Producent
# 7                   KarinAdamsson                  Handelsanställd
# 8                    BirgittaAdde                           Jurist
# 9                   MariaAdelborg                       Formgivare
# 10                OttiliaAdelborg                     Skolgrundare
# 11                GertrudAdelborg                  Styrelseledamot
# 12         LouiseNathaliaAdelborg                   Textilkonstnär
# 13                    AmandaAdler                          Ledamot
# 14                     CeliaAdler                          Ledamot
# 15                  RutMariaAdler  Kommun- och landstingspolitiker
# 16               MariaAdlercreutz                  Förlagsanställd
# 17                MaudAdlercreutz                       Journalist
# 18              SophieAdlersparre               Tidskriftsredaktör
# 19     SophieAdolphineAdlersparre                           Lärare
# 20             MarthaAdlerstrahle                              NaN
# 21                   EvaAdolfsson                       Författare
# 22                    GretaAdrian                       Författare
# 23                  MartaAfzelius                       Formgivare
# 24                    KarinAgeman                           Lärare
# 25                      AnnaAgner                         Konstnär
# 26              AnnaBrittAgnsater                             Chef
# 27                  AlfhildAgrell                       Författare
# 28                  AnnaAgriconia                       Författare
# 29                     LeaAhlborn                           Gravör
# 30               CatharinaAhlgren                      Översättare
# 31               GunnelMariaAhlin                       Författare
# 32                      GerdaAhlm                      Konservator
# 33                   AnnaAhlstrom                       Skolledare
# 34                  AstridAhnfelt                       Journalist
# 35  ClaraFredrikaChristinaAhnfelt                       Författare
# 36          HildaHenriettaAhnfelt             Företagare, fabrikör
# 37                  AnnaAhrenberg                          Donator
# 38                   KarinAhrland                       Tjänsteman
# 39                  ErikaAittamaa                       Företagare
# 40                    LissiAlandh                     Skådespelare
# 41                    ElsieAlbiin                   Teaterdirektör
# 42      MargitMabelGeorginaAlbins                       Tjänsteman
# 43                EvaAlexanderson                       Författare
# 44                VeraAlexandrova                       Författare
# 45               BirgittaAlexius0  Kommun- och landstingspolitiker
# 46                  HarrietAlfons                      Översättare
# 47        AnneMarieAlfvenEriksson               Litteraturkritiker
# 48                      KarinAlin                      Översättare
# 49                 AnnaAlinBosson                           Lärare
#
#                                                detail  occupationtype  \
# 0                                           Gallerist            Yrke
# 1   Litteraturkritiker, BLM, Ord &amp; Bild, Sveri...            Yrke
# 2                                        Operasångare            Yrke
# 3   Dövtolk, föreläsare, arrangör av kurser och fr...            Yrke
# 4   Vissångare, textförfattare, revyartist, bl a A...            Yrke
# 5     Lärare, Konstfackskolan, även Gerlesborgsskolan            Yrke
# 6                                       Filmproducent            Yrke
# 7   Handelsbiträde, sedermera föreståndare, fr o m...            Yrke
# 8                          Lagman, Leksands tingsrätt            Yrke
# 9               Mönsterritare hos Handarbetets Vänner            Yrke
# 10                              Grundade knyppelskola  Ideellt arbete
# 11    Rimforsa lanthushållningsskola, styrelseledamot  Ideellt arbete
# 12               Textilkonstnär, formgivare, konstnär            Yrke
# 13  Ledamot, Karlstads stadsfullmäktiges pensionsk...  Ideellt arbete
# 14         Ledamot, 7:e pensionsdistriktet i Göteborg  Ideellt arbete
# 15        Ledamot, Lindome kommunfullmäktige, för SKP  Ideellt arbete
# 16  Förlagsanställd, Almqvist &amp; Wiksell bokförlag            Yrke
# 17                       Journalist, krönikör, Femina            Yrke
# 18                       Redaktör och skribent, Dagny            Yrke
# 19                               Privatlärare i konst            Yrke
# 20                                                NaN             NaN
# 21                                Författare, essäist            Yrke
# 22                                         Författare            Yrke
# 23                Formgivare, Alice Lund Textilier AB            Yrke
# 24     Lärare i reklam- och bokkonst, Konstfackskolan            Yrke
# 25                                           Konstnär            Yrke
# 26                                   Chef, KF Provkök            Yrke
# 27                                                               Yrke
# 28                          Brev- och dagboksskrivare            Yrke
# 29                    Myntgravör, Kungliga Myntverket            Yrke
# 30                                                               Yrke
# 31                                         Författare            Yrke
# 32              Konservator, Art Institute of Chicago            Yrke
# 33  Skolföreståndare, Nya elementarskolan för flic...            Yrke
# 34                                                               Yrke
# 35                                    Psalmförfattare            Yrke
# 36     Grundare och innehavare, Stockholms Plymfabrik            Yrke
# 37              Donator, bl a till Göteborgs högskola  Ideellt arbete
# 38  Introduktör av främmande sändebud, Utrikesdepa...            Yrke
# 39  Stickare, framför allt vantar, uppfinnare av L...            Yrke
# 40                                                               Yrke
# 41        Grundare, föreståndare, Det Engelske Teater            Yrke
# 42    Anställd vid Amerikanska ambassaden i Stockholm            Yrke
# 43                                         Författare            Yrke
# 44              Författare, även danskritiker, Scenen            Yrke
# 45  Suppleant, Stockholms socialnämnd 1981–1985; l...  Ideellt arbete
# 46                                        Översättare            Yrke
# 47                                 Litteraturkritiker            Yrke
# 48                        Översättare, litterär agent            Yrke
# 49            Lärare, fransk-nordisk folkhögskolekurs            Yrke
#
#                                    from                                   to  \
# 0
# 1   {'comment': '1933', 'date': '1933'}  {'comment': '1967', 'date': '1967'}
# 2                      {'date': '1859'}
# 3             {'comment': '1930-talet'}            {'comment': '1970-talet'}
# 4             {'comment': '1970-talet'}            {'comment': '2000-talet'}
# 5   {'comment': '1971', 'date': '1971'}  {'comment': '1989', 'date': '1989'}
# 6   {'comment': '1933', 'date': '1933'}  {'comment': '1939', 'date': '1939'}
# 7
# 8   {'comment': '1985', 'date': '1985'}  {'comment': '1990', 'date': '1990'}
# 9                      {'date': '1900'}                     {'date': '1907'}
# 10                     {'date': '1903'}
# 11  {'comment': '1907', 'date': '1907'}  {'comment': '1915', 'date': '1915'}
# 12            {'comment': '1910-talet'}            {'comment': '1950-talet'}
# 13            {'comment': '1890-talet'}                     {'comment': '?'}
# 14  {'comment': '1918', 'date': '1918'}  {'comment': '1921', 'date': '1921'}
# 15  {'comment': '1946', 'date': '1946'}                     {'comment': '?'}
# 16  {'comment': '1980', 'date': '1980'}  {'comment': '1987', 'date': '1987'}
# 17            {'comment': '1970-talet'}
# 18  {'comment': '1886', 'date': '1886'}  {'comment': '1895', 'date': '1895'}
# 19            {'comment': '1840-talet'}  {'comment': '1850', 'date': '1850'}
# 20                                  NaN                                  NaN
# 21  {'comment': '1980', 'date': '1980'}  {'comment': '2009', 'date': '2009'}
# 22
# 23
# 24  {'comment': '1945', 'date': '1945'}  {'comment': '1950', 'date': '1950'}
# 25            {'comment': '1920-talet'}                     {'comment': '?'}
# 26  {'comment': '1946', 'date': '1946'}  {'comment': '1980', 'date': '1980'}
# 27
# 28  {'comment': '1684', 'date': '1684'}  {'comment': '1688', 'date': '1688'}
# 29                     {'date': '1855'}                     {'date': '1897'}
# 30  {'comment': '1772', 'date': '1772'}               {'comment': 'ca 1810'}
# 31  {'comment': '1960', 'date': '1960'}  {'comment': '2005', 'date': '2005'}
# 32
# 33  {'comment': '1902', 'date': '1902'}  {'comment': '1943', 'date': '1943'}
# 34  {'comment': '1898', 'date': '1898'}                     {'comment': '?'}
# 35  {'comment': '1859', 'date': '1859'}                     {'comment': '?'}
# 36  {'comment': '1879', 'date': '1879'}  {'comment': '1914', 'date': '1914'}
# 37
# 38  {'comment': '1995', 'date': '1995'}  {'comment': '2006', 'date': '2006'}
# 39            {'comment': '1890-talet'}  {'comment': '1952', 'date': '1952'}
# 40  {'comment': '1952', 'date': '1952'}
# 41            {'comment': '1960-talet'}            {'comment': '1970-talet'}
# 42  {'comment': '1942', 'date': '1942'}  {'comment': '1948', 'date': '1948'}
# 43  {'comment': '1954', 'date': '1954'}  {'comment': '1994', 'date': '1994'}
# 44            {'comment': '1920-talet'}                     {'comment': '?'}
# 45  {'comment': '1981', 'date': '1981'}  {'comment': '1985', 'date': '1985'}
# 46            {'comment': '1940-talet'}            {'comment': '2000-talet'}
# 47
# 48  {'comment': '1936', 'date': '1936'}            {'comment': '1970-talet'}
# 49               {'comment': 'Ca 1952'}  {'comment': '1954', 'date': '1954'}
#
#                                                 place
# 0   {'pin': {'lat': 56.245748, 'lon': 12.863881}, ...
# 1   {'pin': {'lat': 59.858564, 'lon': 17.638927}, ...
# 2   {'pin': {'lat': '48.208174', 'lon': '16.373819...
# 3   {'pin': {'lat': '57.70887', 'lon': '11.97456'}...
# 4
# 5   {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 6   {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 7   {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 8   {'pin': {'lat': 60.730308, 'lon': 14.999892}, ...
# 9   {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 10  {'pin': {'lat': '60.590983', 'lon': '15.070049...
# 11
# 12  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 13  {'pin': {'lat': 59.402181, 'lon': 13.511498}, ...
# 14  {'pin': {'lat': 57.70887, 'lon': 11.97456}, 'p...
# 15  {'pin': {'lat': 57.5791257, 'lon': 12.0876599}...
# 16  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 17  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 18  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 19  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 20                                                NaN
# 21  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 22
# 23  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 24  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 25
# 26  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 27
# 28  {'pin': {'lat': '39.074208', 'lon': '21.824312...
# 29  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 30
# 31
# 32  {'pin': {'lat': 41.878114, 'lon': -87.629798},...
# 33  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 34  {'pin': {'lat': '41.902701', 'lon': '12.496235...
# 35  {'pin': {'lat': 56.170303, 'lon': 14.863073}, ...
# 36  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 37  {'pin': {'lat': 57.70887, 'lon': 11.97456}, 'p...
# 38  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 39  {'pin': {'lat': 67.3403184, 'lon': 22.6105034}...
# 40  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 41  {'pin': {'lat': 55.676097, 'lon': 12.568337}, ...
# 42  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 43
# 44  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 45  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 46  {'pin': {'lat': 59.329323, 'lon': 18.068581}, ...
# 47
# 48
# 49  {'pin': {'lat': 48.6452851, 'lon': 1.819207}, ...

# %%
newListdf["skblid"].value_counts()
# Out:
# EvaLowen                   1
# ElfriedeKolbeDobrowolny    1
# HildurKristinaEricsson     1
# HelfridLofquist            1
# NinniKronberg              1
#                           ..
# HannaAugustaFerlin         1
# AnnastinaAlkman            1
# CatharinaWallenstedt       1
# SaraThastrom               1
# MettaLillie                1
# Name: skblid, Length: 2055, dtype: int64

# %%
Yrkendf = newListdf["description"].value_counts()
Yrkendf
# Out:
# Författare                          208
# Lärare                              147
# Konstnär                            114
# Skådespelare                         80
# Socialt och filantropiskt arbete     66
#                                    ...
# Telefonist                            1
# Etnolog                               1
# Soldat                                1
# Antikvarie                            1
# Förmyndare                            1
# Name: description, Length: 229, dtype: int64

# %%
newListdf["occupationtype"].value_counts()
# Out:
# Yrke              1681
# Ideellt arbete     357
# Name: occupationtype, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)
ax = Yrkendf.plot(kind='pie')

ax.set_title("Vanligaste Yrken i SKBL " + start_time.strftime('%Y %m %d'))
# Out:
# Text(0.5, 1.0, 'Vanligaste Yrken i SKBL 2021 08 17')

# %%
fig = ax.get_figure()
plt.rcParams['savefig.facecolor']='white'
fig.savefig('../img/SKBL_yrken_json.png')

# %%
newListdf.to_csv("SKBLyrken_newListdf.csv")
Yrkendf.to_csv("SKBLyrken_valuecount.csv")
